# %%
import pandas as pd

# %%
df=pd.read_csv("personality_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2837 non-null   float64
#  1   Stage_fear                 2827 non-null   object
#  2   Social_event_attendance    2838 non-null   float64
#  3   Going_outside              2834 non-null   float64
#  4   Drained_after_socializing  2848 non-null   object
#  5   Friends_circle_size        2823 non-null   float64
#  6   Post_frequency             2835 non-null   float64
#  7   Personality                2900 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 181.4+ KB

# %%
df
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            NaN
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                           No                 13.0             5.0
# 1                          Yes                  0.0             3.0
# 2                          Yes                  5.0             2.0
# 3                           No                 14.0             8.0
# 4                           No                  8.0             5.0
# ...                        ...                  ...             ...
# 2895                        No                  6.0             6.0
# 2896                        No                 14.0             9.0
# 2897                       Yes                  4.0             0.0
# 2898                       Yes                  2.0             0.0
# 2899                        No                  6.0             9.0
#
#      Personality
# 0      Extrovert
# 1      Introvert
# 2      Introvert
# 3      Extrovert
# 4      Extrovert
# ...          ...
# 2895   Extrovert
# 2896   Extrovert
# 2897   Introvert
# 2898   Introvert
# 2899   Extrovert
#
# [2900 rows x 8 columns]

# %%
df.describe()
# Out:
#        Time_spent_Alone  Social_event_attendance  Going_outside  \
# count       2837.000000              2838.000000    2834.000000
# mean           4.505816                 3.963354       3.000000
# std            3.479192                 2.903827       2.247327
# min            0.000000                 0.000000       0.000000
# 25%            2.000000                 2.000000       1.000000
# 50%            4.000000                 3.000000       3.000000
# 75%            8.000000                 6.000000       5.000000
# max           11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count          2823.000000     2835.000000
# mean              6.268863        3.564727
# std               4.289693        2.926582
# min               0.000000        0.000000
# 25%               3.000000        1.000000
# 50%               5.000000        3.000000
# 75%              10.000000        6.000000
# max              15.000000       10.000000

# %%
df.isna().sum()
# Out:
# Time_spent_Alone             63
# Stage_fear                   73
# Social_event_attendance      62
# Going_outside                66
# Drained_after_socializing    52
# Friends_circle_size          77
# Post_frequency               65
# Personality                   0
# dtype: int64

# %%
df=df.dropna(subset=['Drained_after_socializing'])

# %%
df
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            NaN
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                           No                 13.0             5.0
# 1                          Yes                  0.0             3.0
# 2                          Yes                  5.0             2.0
# 3                           No                 14.0             8.0
# 4                           No                  8.0             5.0
# ...                        ...                  ...             ...
# 2895                        No                  6.0             6.0
# 2896                        No                 14.0             9.0
# 2897                       Yes                  4.0             0.0
# 2898                       Yes                  2.0             0.0
# 2899                        No                  6.0             9.0
#
#      Personality
# 0      Extrovert
# 1      Introvert
# 2      Introvert
# 3      Extrovert
# 4      Extrovert
# ...          ...
# 2895   Extrovert
# 2896   Extrovert
# 2897   Introvert
# 2898   Introvert
# 2899   Extrovert
#
# [2848 rows x 8 columns]

# %%
df['Time_spent_Alone'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
df
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2892               9.0        Yes                      2.0            0.0
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                           No                 13.0             5.0
# 1                          Yes                  0.0             3.0
# 2                          Yes                  5.0             2.0
# 3                           No                 14.0             8.0
# 4                           No                  8.0             5.0
# ...                        ...                  ...             ...
# 2892                       Yes                  1.0             2.0
# 2895                        No                  6.0             6.0
# 2896                        No                 14.0             9.0
# 2897                       Yes                  4.0             0.0
# 2899                        No                  6.0             9.0
#
#      Personality
# 0      Extrovert
# 1      Introvert
# 2      Introvert
# 3      Extrovert
# 4      Extrovert
# ...          ...
# 2892   Introvert
# 2895   Extrovert
# 2896   Extrovert
# 2897   Introvert
# 2899   Extrovert
#
# [2477 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
col=['Personality','Drained_after_socializing','Stage_fear']

# %%
for i in col:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0           0                      4.0            6.0
# 1                  9.0           1                      0.0            0.0
# 2                  9.0           1                      1.0            2.0
# 3                  0.0           0                      6.0            7.0
# 4                  3.0           0                      9.0            4.0
# ...                ...         ...                      ...            ...
# 2892               9.0           1                      2.0            0.0
# 2895               3.0           0                      7.0            6.0
# 2896               3.0           0                      8.0            3.0
# 2897               4.0           1                      1.0            1.0
# 2899               3.0           0                      6.0            6.0
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                             0                 13.0             5.0
# 1                             1                  0.0             3.0
# 2                             1                  5.0             2.0
# 3                             0                 14.0             8.0
# 4                             0                  8.0             5.0
# ...                         ...                  ...             ...
# 2892                          1                  1.0             2.0
# 2895                          0                  6.0             6.0
# 2896                          0                 14.0             9.0
# 2897                          1                  4.0             0.0
# 2899                          0                  6.0             9.0
#
#       Personality
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0
# ...           ...
# 2892            1
# 2895            0
# 2896            0
# 2897            1
# 2899            0
#
# [2477 rows x 8 columns]

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['Going_outside'])
# Out:
# <Axes: xlabel='Going_outside'>

# %%
df['Time_spent_Alone'].value_counts()
# Out:
# Time_spent_Alone
# -1.295649    323
# -0.722658    320
# -0.436162    302
# -1.009153    278
#  1.282810    183
#  1.569306    171
# -0.149667    168
#  0.709819    166
#  0.996315    155
#  0.136828    154
#  0.423324    130
#  1.855801    127
# Name: count, dtype: int64

# %%
sns.boxplot(x=df['Social_event_attendance'])
# Out:
# <Axes: xlabel='Social_event_attendance'>

# %%
df.describe()
# Out:
#        Time_spent_Alone   Stage_fear  Social_event_attendance  Going_outside  \
# count      2.477000e+03  2477.000000             2.477000e+03   2.477000e+03
# mean       6.310836e-17     0.498991            -2.868562e-17   4.589699e-17
# std        1.000202e+00     0.500100             1.000202e+00   1.000202e+00
# min       -1.295649e+00     0.000000            -1.358543e+00  -1.335408e+00
# 25%       -7.226579e-01     0.000000            -6.687590e-01  -8.922995e-01
# 50%       -1.496670e-01     0.000000            -3.238671e-01  -6.082234e-03
# 75%        9.963148e-01     1.000000             7.108088e-01   8.801350e-01
# max        1.855801e+00     1.000000             2.090377e+00   1.766352e+00
#
#        Drained_after_socializing  Friends_circle_size  Post_frequency  \
# count                2477.000000         2.477000e+03     2477.000000
# mean                    0.498991         1.721137e-17        3.559548
# std                     0.500100         1.000202e+00        2.927397
# min                     0.000000        -1.447585e+00        0.000000
# 25%                     0.000000        -7.516090e-01        1.000000
# 50%                     0.000000        -2.876251e-01        3.000000
# 75%                     1.000000         8.723347e-01        6.000000
# max                     1.000000         2.032294e+00       10.000000
#
#        Personality
# count  2477.000000
# mean      0.485668
# std       0.499895
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.drop_duplicates()
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0            -0.149667           0                 0.021025       1.323244
# 1             1.282810           1                -1.358543      -1.335408
# 2             1.282810           1                -1.013651      -0.449191
# 3            -1.295649           0                 0.710809       1.766352
# 4            -0.436162           0                 1.745485       0.437026
# ...                ...         ...                      ...            ...
# 2888          0.136828           1                -1.358543      -0.892299
# 2889          0.423324           1                -1.358543      -1.335408
# 2896         -0.436162           0                 1.400593      -0.006082
# 2897         -0.149667           1                -1.013651      -0.892299
# 2899         -0.436162           0                 0.710809       1.323244
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                             0             1.568311             5.0
# 1                             1            -1.447585             3.0
# 2                             1            -0.287625             2.0
# 3                             0             1.800303             8.0
# 4                             0             0.408351             5.0
# ...                         ...                  ...             ...
# 2888                          1            -1.215593             0.0
# 2889                          1            -0.751609             0.0
# 2896                          0             1.800303             9.0
# 2897                          1            -0.519617             0.0
# 2899                          0            -0.055633             9.0
#
#       Personality
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0
# ...           ...
# 2888            1
# 2889            1
# 2896            0
# 2897            1
# 2899            0
#
# [2098 rows x 8 columns]

# %%
Q1 = df['Social_event_attendance'].quantile(0)
Q3 = df['Social_event_attendance'].quantile(1)
IQR = Q3 - Q1

lower_bound = Q1 - 0 * IQR
upper_bound = Q3 + 1 * IQR

df_no_outliers = df[(df['Social_event_attendance'] >= lower_bound) & (df['Social_event_attendance'] <= upper_bound)]

# %%
upper=df['Social_event_attendance']*(0)+3*df['Social_event_attendance']*(1)
lower=df['Social_event_attendance']*(0)-3*df['Social_event_attendance']*(1)
print(upper)
print(lower)
# Out:
# 0       0.063075
# 1      -4.075629
# 2      -3.040953
# 3       2.132426
# 4       5.236454
#           ...
# 2892   -2.006277
# 2895    3.167102
# 2896    4.201778
# 2897   -3.040953
# 2899    2.132426
# Name: Social_event_attendance, Length: 2477, dtype: float64
# 0      -0.063075
# 1       4.075629
# 2       3.040953
# 3      -2.132426
# 4      -5.236454
#           ...
# 2892    2.006277
# 2895   -3.167102
# 2896   -4.201778
# 2897    3.040953
# 2899   -2.132426
# Name: Social_event_attendance, Length: 2477, dtype: float64

# %%
df.loc[(df['Social_event_attendance']>upper) | (df['Social_event_attendance']<lower)]
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 1             1.282810           1                -1.358543      -1.335408
# 2             1.282810           1                -1.013651      -0.449191
# 8             1.569306           1                -1.013651      -0.006082
# 11            1.569306           1                -0.323867      -0.892299
# 14            0.423324           1                -0.323867      -1.335408
# ...                ...         ...                      ...            ...
# 2889          0.423324           1                -1.358543      -1.335408
# 2890          0.996315           1                -0.668759      -1.335408
# 2891          0.423324           1                -0.323867      -0.892299
# 2892          1.282810           1                -0.668759      -1.335408
# 2897         -0.149667           1                -1.013651      -0.892299
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 1                             1            -1.447585             3.0
# 2                             1            -0.287625             2.0
# 8                             1            -1.447585             3.0
# 11                            1            -0.519617             0.0
# 14                            1            -1.215593             3.0
# ...                         ...                  ...             ...
# 2889                          1            -0.751609             0.0
# 2890                          1            -1.215593             2.0
# 2891                          1            -0.287625             1.0
# 2892                          1            -1.215593             2.0
# 2897                          1            -0.519617             0.0
#
#       Personality
# 1               1
# 2               1
# 8               1
# 11              1
# 14              1
# ...           ...
# 2889            1
# 2890            1
# 2891            1
# 2892            1
# 2897            1
#
# [1251 rows x 8 columns]

# %%
df.loc[(df['Social_event_attendance']<upper) & (df['Social_event_attendance']>lower)]
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0            -0.149667           0                 0.021025       1.323244
# 3            -1.295649           0                 0.710809       1.766352
# 4            -0.436162           0                 1.745485       0.437026
# 5            -1.009153           0                 1.055701       0.880135
# 7            -0.722658           0                 1.400593       0.437026
# ...                ...         ...                      ...            ...
# 2880         -1.295649           0                 0.710809      -0.006082
# 2887         -1.295649           0                 1.745485       1.323244
# 2895         -0.436162           0                 1.055701       1.323244
# 2896         -0.436162           0                 1.400593      -0.006082
# 2899         -0.436162           0                 0.710809       1.323244
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                             0             1.568311             5.0
# 3                             0             1.800303             8.0
# 4                             0             0.408351             5.0
# 5                             0            -0.055633             6.0
# 7                             0             0.176359             8.0
# ...                         ...                  ...             ...
# 2880                          0             0.176359             5.0
# 2887                          0            -0.055633             3.0
# 2895                          0            -0.055633             6.0
# 2896                          0             1.800303             9.0
# 2899                          0            -0.055633             9.0
#
#       Personality
# 0               0
# 3               0
# 4               0
# 5               0
# 7               0
# ...           ...
# 2880            0
# 2887            0
# 2895            0
# 2896            0
# 2899            0
#
# [1226 rows x 8 columns]

# %%
df
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0            -0.149667           0                 0.021025       1.323244
# 1             1.282810           1                -1.358543      -1.335408
# 2             1.282810           1                -1.013651      -0.449191
# 3            -1.295649           0                 0.710809       1.766352
# 4            -0.436162           0                 1.745485       0.437026
# ...                ...         ...                      ...            ...
# 2892          1.282810           1                -0.668759      -1.335408
# 2895         -0.436162           0                 1.055701       1.323244
# 2896         -0.436162           0                 1.400593      -0.006082
# 2897         -0.149667           1                -1.013651      -0.892299
# 2899         -0.436162           0                 0.710809       1.323244
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                             0             1.568311             5.0
# 1                             1            -1.447585             3.0
# 2                             1            -0.287625             2.0
# 3                             0             1.800303             8.0
# 4                             0             0.408351             5.0
# ...                         ...                  ...             ...
# 2892                          1            -1.215593             2.0
# 2895                          0            -0.055633             6.0
# 2896                          0             1.800303             9.0
# 2897                          1            -0.519617             0.0
# 2899                          0            -0.055633             9.0
#
#       Personality
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0
# ...           ...
# 2892            1
# 2895            0
# 2896            0
# 2897            1
# 2899            0
#
# [2477 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold,cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
scaler=StandardScaler()

# %%
col=['Time_spent_Alone','Social_event_attendance','Going_outside','Friends_circle_size']
for j in col:
    df[j]=scaler.fit_transform(df[[j]])

# %%
df
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0            -0.149667           0                 0.021025       1.323244
# 1             1.282810           1                -1.358543      -1.335408
# 2             1.282810           1                -1.013651      -0.449191
# 3            -1.295649           0                 0.710809       1.766352
# 4            -0.436162           0                 1.745485       0.437026
# ...                ...         ...                      ...            ...
# 2892          1.282810           1                -0.668759      -1.335408
# 2895         -0.436162           0                 1.055701       1.323244
# 2896         -0.436162           0                 1.400593      -0.006082
# 2897         -0.149667           1                -1.013651      -0.892299
# 2899         -0.436162           0                 0.710809       1.323244
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                             0             1.568311             5.0
# 1                             1            -1.447585             3.0
# 2                             1            -0.287625             2.0
# 3                             0             1.800303             8.0
# 4                             0             0.408351             5.0
# ...                         ...                  ...             ...
# 2892                          1            -1.215593             2.0
# 2895                          0            -0.055633             6.0
# 2896                          0             1.800303             9.0
# 2897                          1            -0.519617             0.0
# 2899                          0            -0.055633             9.0
#
#       Personality
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0
# ...           ...
# 2892            1
# 2895            0
# 2896            0
# 2897            1
# 2899            0
#
# [2477 rows x 8 columns]

# %%
X=df[['Time_spent_Alone','Stage_fear','Drained_after_socializing']]
y=df['Personality']

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pre=model.predict(X_test)
r2_score(y_test,y_pre)
# Out:
# 0.733423807419908
